# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# # IST 718: Big Data Analytics
#
# - Professor:  Humayun Khan <hhkhan@syr.edu>
# - Faculty Assistant: Rashika Pramod Singh <rsingh37@syr.edu>
# - Faculty Assistant: Rohan Nitin Mahajan <rmahaj01@syr.edu>
# ## General instructions:
#
# - You are welcome to discuss the problems with your classmates but __you are not allowed to copy any part of your answers from your classmates.  Short code snippets are allowed from the internet.  Code from the class text books or class provided code can be copied in its entirety.__
# - There could be tests in some cells (i.e., `assert` and `np.testing.` statements). These tests (if present) are used to grade your answers. **However, the professor and FAs could use __additional__ test for your answer. Think about cases where your code should run even if it passess all the tests you see.**
# - Before submitting your work, remember to check for run time errors with the following procedure:
# `Kernel`$\rightarrow$`Restart and Run All`.  All runtime errors will result in a minimum penalty of half off.
# - Data Bricks is the official class runtime environment so you should test your code on Data Bricks before submission.  If there is a runtime problem in the grading environment, we will try your code on Data Bricks before making a final grading decision.
# - All plots shall include a title, and axis labels.  Unless stated otherwise, plots can be made using your favorite Python plotting package.
# - Grading feedback cells are there for graders to provide feedback to students.  Don't change or remove grading feedback cells.
# - Don't add or remove files from your git repo.
# - Do not change file names in your repo.  This also means don't change the title of the ipython notebook.
# - You are free to add additional code cells around the cells marked `your code here`.
# - Students may use toPandas() to print the head of data frames.
# - We reserve the right to take points off for operations that are extremely inefficient.  This is a big data class and extremely inefficient operations make a big difference when scaling up to large data sets.
# - Students are responsible for reading the usage comments and understanding how to properly use the utility functions (like get_training_filename()) provided in the assignments.  Runtime errors which result from incorrect usage of utility functions shall result in a  point reduction.
# - import * is not allowed because it is considered a very bad coding practice and in some cases can result in a significant delay (which slows down the grading process) in loading imports.  For example, the statement `from sympy import *` is not allowed.  You must import the specific packages that you need.
# - If you perform databricks specific operations, you MUST protect those operations in an if statement by calling the is_databricks() function provided in all homework assignments.  For example, if you use dbutils (databricks utilities), only run dbutils commands if is_databricks() returns true.  Runtime errors created in the grading environment by not protecting databricks specific commands in an if statement will result in a runtime error points deduction.
# - The graders reserve the right to deduct points for subjective things we see with your code.  For example, if we ask you to create a pandas data frame to display values from an investigation and you hard code the values, we will take points off for that.  This is only one of many different things we could find in reviewing your code.  In general, write your code like you are submitting it for a code peer review in industry.
# - Level of effort is part of our subjective grading.  Oftentimes there is a large disparity between the level of effort between students who are trying learn, and students who are trying to do the minimum possible to check off an assignment requirement.  For example, in cases where we ask for a more open ended investigation, some students put in significant effort and some students do the minimum possible to meet requirements.  In these cases, we may take points off for students who did not put in much effort as compared to students who did put in a lot of effort.  We feel that the students who did a better job deserve a better grade.  We reserve the right to invoke level of effort grading at any time.
# - __Only use spark, spark machine learning, spark data frames, RDD's, and map reduce to solve all problems unless instructed otherwise.  Heavy weight operations that convert data to pandas or spark (like collect()) will result in a point reduction.__

# %%
# Do not delete or change this cell

# grading import statements
from pyspark.sql import SparkSession
from pyspark.sql import SQLContext
spark = SparkSession.builder.getOrCreate()
sc = spark.sparkContext
sqlContext = SQLContext(sc)
import os

# Define a function to determine if we are running on data bricks
# Return true if running in the data bricks environment, false otherwise
def is_databricks():
    # get the databricks runtime version
    db_env = os.getenv("DATABRICKS_RUNTIME_VERSION")
    
    # if running on data bricks
    if db_env != None:
        return True
    else:
        return False

# Define a function to read the data file.  The full path data file name is constructed
# by checking runtime environment variables to determine if the runtime environment is 
# databricks, or a student's personal computer.  The full path file name is then
# constructed based on the runtime env.
# 
# Params
#   data_file_name: The base name of the data file to load
# 
# Returns the full path file name based on the runtime env
#
# Correct Usage Example (pass ONLY the full file name):
#   file_name_to_load = get_training_filename("sms_spam.csv") # correct - pass ONLY the full file name  
#   
# Incorrect Usage Example
#   file_name_to_load = get_training_filename("/sms_spam.csv") # incorrect - pass ONLY the full file name
#   file_name_to_load = get_training_filename("sms_spam.csv/") # incorrect - pass ONLY the full file name
#   file_name_to_load = get_training_filename("c:/users/will/data/sms_spam.csv") incorrect -pass ONLY the full file name
def get_training_filename(data_file_name):    
    # if running on data bricks
    if is_databricks():
        # build the full path file name assuming data brick env
        full_path_name = "/FileStore/tables/%s" % data_file_name
    # else the data is assumed to be in the same dir as this notebook
    else:
        # Assume the student is running on their own computer and load the data
        # file from the same dir as this notebook
        full_path_name = data_file_name
    
    # return the full path file name to the caller
    return full_path_name
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-95-e1f89434245a> in <module>
#       2
#       3 # grading import statements
# ----> 4 from pyspark.sql import SparkSession
#       5 from pyspark.sql import SQLContext
#       6 spark = SparkSession.builder.getOrCreate()
#
# ModuleNotFoundError: No module named 'pyspark'

# %%
# Importing required libraries
import random 
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# # Question 1 (10 pts)
# In the game of [roullete](https://en.wikipedia.org/wiki/Roulette) you can bet on several things including if the ball will land on black or red. In a black or red bet, if you win, you double your earnings. How does the casino make money? If you look at the possibilities you realize that the chance of red or black are both slightly less than 1/2. There are two green spots, so the chance of landing on black (or red) is actually 18/38, or 9/19.<br>
# Create a utility function which can be used in a monte carlo simulation named get_outcome. The get_outcome function takes as an argument the number of times you play (or spin) the roulette wheel and returns the player's earnings for the number of spins specified.  Assume that the player bets exactly one dollar on black for each spin of the wheel.

# %%
# your code here
def get_outcome(no_spins):
    bet_black = 1
    total_earn = 0
    while(no_spins != 0):
        # Either the outcome is "Black" or "Not-Black"
        # We define this using the get_rand
        outcome = random.randint(1,39)
        if outcome <= 18:
            total_earn += 2*bet_black
        else:
            total_earn -= bet_black
        no_spins -= 1
    return total_earn

# %%
# Grading cell - do not change or delete
num_plays = 10000
get_outcome(num_plays) / num_plays
# Out:
# 0.3752

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# # Question 2 (10 pts)
# Using the get_outcome function defined above, use a monte carlo simulation to study the distribution of total earnings.  Run 4 simulations for number of roulette plays = 10, 25, 100, and 1000 where each of the 4 simulations is executed 500 times.  Collect the results into a 2 dimensional numpy array named roulette_sim_array.  The data frame shall have 4 labeled columns where each column contains data from each of the 4 simulations. Create histograms that show the distributions of total earnings for the 4 simulations.  Based on the histogram plots, describe what happens to toal earnings as the number of plays increases.

# %%
# your code here
no_sims = 500

roulette_sim_array = np.empty((no_sims,4))

for sim in range(no_sims):
    roulette_sim_array[sim,0] = get_outcome(10)
    roulette_sim_array[sim,1] = get_outcome(25)
    roulette_sim_array[sim,2] = get_outcome(100)
    roulette_sim_array[sim,3] = get_outcome(1000)
roulette_sim_array
# Out:
# array([[  2.,  -1.,  23., 449.],
#        [ -4.,   8.,  47., 431.],
#        [ 11.,   5.,  29., 413.],
#        ...,
#        [  8.,   8.,  53., 347.],
#        [  8.,  20.,  26., 401.],
#        [ -1.,   2.,  56., 455.]])

# %%
# Histograms
# no_plays = 10
hist_10 = plt.hist(roulette_sim_array[:,0],edgecolor = 'black')
hist_10
# Out:
# (array([  8.,  39.,  75., 109.,   0., 104.,  86.,  60.,  18.,   1.]),
#  array([-7. , -4.6, -2.2,  0.2,  2.6,  5. ,  7.4,  9.8, 12.2, 14.6, 17. ]),
#  <a list of 10 Patch objects>)

# %%
# no_plays = 25
hist_25 = plt.hist(roulette_sim_array[:,1],edgecolor = 'black')
hist_25
# Out:
# (array([ 10.,  12.,  73.,  63., 162.,  66.,  79.,  17.,  17.,   1.]),
#  array([-10. ,  -5.5,  -1. ,   3.5,   8. ,  12.5,  17. ,  21.5,  26. ,
#          30.5,  35. ]),
#  <a list of 10 Patch objects>)

# %%
# no_plays = 100
hist_100 = plt.hist(roulette_sim_array[:,2],edgecolor = 'black')
hist_100
# Out:
# (array([  2.,   7.,  21.,  60., 115., 124.,  90.,  53.,  20.,   8.]),
#  array([-10. ,  -1.3,   7.4,  16.1,  24.8,  33.5,  42.2,  50.9,  59.6,
#          68.3,  77. ]),
#  <a list of 10 Patch objects>)

# %%
# no_plays = 1000
hist_1000 = plt.hist(roulette_sim_array[:,3],edgecolor = 'black')
hist_1000
# Out:
# (array([  4.,  24.,  60.,  88., 113., 104.,  63.,  34.,   6.,   4.]),
#  array([251. , 279.5, 308. , 336.5, 365. , 393.5, 422. , 450.5, 479. ,
#         507.5, 536. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# Your explanation here:<br> As the number of games increases, the total earnings decreases

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# # Question 3 (10 pts)
# Using the central limit theorem, create a pandas dataframe named roulette_df containing the sampling distribution of the means from the sample data in the numpy array above.  The pandas dataframe should have 4 columns labeled with the simulation names. Using data in the roulette_df, plot histograms for each of the sampling distributions - you should have 4 histograms in total.<br>  Assuming you don't know the underlying distribution of the population from which the samples were drawn, some of the histograms are gauranteed to be Gaussian in shape, some are not gauranteed, and some are in a transition region. For each of the 4 simulations, describe if you think the shape is gauranteed to be gaussian, not gauranteed to be Gaussian, or in a transition area between a gaurantee and no gaurantee.

# %%
# Your histogram code here

roulette_df = pd.DataFrame(columns= [10, 25, 100, 1000])

for ctr in range(1000):
    sample = []
    for ctr1 in range(0,roulette_sim_array.shape[1]):
        sam_data = np.random.choice(roulette_sim_array[ctr1],size = 100)
        mean_samdata = np.mean(sam_data)
        sample.append(mean_samdata)
    
    roulette_df.loc[len(roulette_df)] = sample

# %%
# Histogram with number of plays "10"
plt.hist(roulette_df[10],edgecolor = 'black', color = 'white')
plt.title('Histogram with num_plays = 10')
plt.show()

# %%
# Histogram with number of plays "25"
plt.hist(roulette_df[25],edgecolor = 'black', color = 'white')
plt.title('Histogram with num_plays = 25')
plt.show()

# %%
# Histogram with number of plays "100"
plt.hist(roulette_df[100],edgecolor = 'black', color = 'white')
plt.title('Histogram with num_plays = 100')
plt.show()

# %%
# Histogram with number of plays "1000"
plt.hist(roulette_df[1000],edgecolor = 'black', color = 'white')
plt.title('Histogram with num_plays = 1000')
plt.show()

# %%
# Grading cell - do not modify
roulette_df.head()
# Out:
#      10      25      100     1000
# 0  156.86  120.26  122.24  104.39
# 1  125.66  118.79  123.26  103.16
# 2  120.98   90.17  125.96   92.75
# 3  126.80  109.22  145.88  114.29
# 4   88.01  130.49   99.38   84.02

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# Your explanation here:<br> When the number of plays is "10", its not gaussian but when number of plays is "25"  or "100", its mostlty in a transistion area between a gurantee and no gurantee and when the number of plays is "1000" the shape is guranteed to be gaussian

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# # Question 4 (20 pts)
# Create a new monte carlo simulation that calculates the probability that the casino loses money based on the number of times that a player plays roulette.  Create a function p_casino_loss that takes as an argument the number of times that the player plays roulette, and returns the probability that the casino loses money.  Using data collected from p_casino_loss, produce a line plot that shows the probability that the casino loses money vs. the number of games played for number of games between 25 and 1000.  Describe what the results of the simulation show.

# %%
# your code here

# Here it is assumed that numbers from 1 to 18 are considered "black" and from 19 to 36 are considered "red" and the remaining 2 
# from 36 to 38 are considered "green"

def p_casino_loss(num_plays):
    wins=2
    for ctr in range(num_plays):
        spin_outcome = random.randint(1,39)
        if spin_outcome <= 18:
            count =+ 1
    return count/num_plays

# %%
# Line Plot
no_games = [ctr for ctr in range(25,1000)]  # filling in the number of games in the arraya

prob_list = [p_casino_loss(no_games) for no_games in range(25,1000)] # filling in the probabilities using the p_casino_loss() into "Prob_list"

plt.plot(no_games,prob_list) # line plot for Prob of casino loss VS no of games played
plt.xlabel("No. of games")
plt.ylabel("Probability of casino loss")
# Out:
# Text(0, 0.5, 'Probability of casino loss')

# %% [markdown]
# Your explanation here:<br> As the No of games increases the probability of casino losing money exponentially decreases

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# # Question 5 (10 pts)
# Compute the following matrix dot product manually by creating 2 dimensinal nympy arrays for each matrix, computing the matrix multiply using for loops, and loading a new 2 dimensional numpy array with the answer.  Print the resulting numpy array.
#
# $$
# \quad
# \begin{bmatrix}
# 3 & 7 \\
# 6 & 9 \\
# 4 & 2 \\
# \end{bmatrix}
# \quad
# *
# \quad
# \begin{bmatrix}
# 2 & 5 & 7\\
# 2 & 5 & 1
# \end{bmatrix}
# \quad
# $$

# %%
# your code here
mat1 = np.array([[3, 7],
               [6, 9],
               [4, 2]])
mat2 = np.array([[2, 5, 7],
                 [2, 5, 1]])
mat3 = np.zeros((mat1.shape[0],mat2.shape[1]))
# using for loops and dot function to perform the multiplication
for ctr in range(mat1.shape[0]):
    for ctr2 in range(mat2.shape[1]):
        for ctr3 in range(mat2.shape[0]):
            mat3[ctr,ctr2] += mat1[ctr,ctr3]*mat2[ctr3,ctr2]
            
mat3
# Out:
# array([[20., 50., 28.],
#        [30., 75., 51.],
#        [12., 30., 30.]])

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# # Question 6 (10 pts)
# Read each of the csv files in your assignment repo into pandas dataframes named population_df, morttality_df, life_exp_df, and fertility_df.  Rename the column with the country names as "Country" in each of the dataframes.

# %%
# your code here
population_df = pd.read_csv('indicator gapminder population - Data.csv')
population_df = population_df.rename(columns = {'Total population': 'Country'})

morttality_df = pd.read_csv('indicator gapminder under5mortality - Data.csv')
morttality_df = morttality_df.rename(columns = {'Under five mortality': 'Country'})

life_exp_df = pd.read_csv('indicator life_expectancy_at_birth - Data.csv')
life_exp_df = life_exp_df.rename(columns = {'Life expectancy with projections. Yellow is IHME': 'Country'})

fertility_df = pd.read_csv('indicator undata total_fertility - Data.csv')
fertility_df = fertility_df.rename(columns = {'Total fertility rate': 'Country'})

display(population_df.head())
display(morttality_df.head())
display(life_exp_df.head())
display(fertility_df.head())
# Out:
#                  Country       1800     1810     1820     1830     1840  \
# 0               Abkhazia        NaN      NaN      NaN      NaN      NaN
# 1            Afghanistan    3280000  3280000  3323519  3448982  3625022
# 2  Akrotiri and Dhekelia        NaN      NaN      NaN      NaN      NaN
# 3                Albania    410,445   423591   438671   457234   478227
# 4                Algeria  2,503,218  2595056  2713079  2880355  3082721
#
#       1850     1860     1870     1880    ...         2006      2007      2008  \
# 0      NaN      NaN      NaN      NaN    ...          NaN       NaN       NaN
# 1  3810047  3973968  4169690  4419695    ...     25183615  25877544  26528741
# 2      NaN      NaN      NaN      NaN    ...        15700     15700     15700
# 3   506889   552800   610036   672544    ...      3050741   3010849   2968026
# 4  3299305  3536468  3811028  4143163    ...     33749328  34261971  34811059
#
#        2009      2010      2011      2012      2013      2014      2015
# 0       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1  27207291  27962207  28809167  29726803  30682500  31627506  32526562
# 2       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3   2929886   2901883   2886010   2880667   2883281   2889676   2896679
# 4  35401790  36036159  36717132  37439427  38186135  38934334  39666519
#
# [5 rows x 82 columns]
#                  Country    1800    1801    1802    1803    1804    1805  \
# 0               Abkhazia     NaN     NaN     NaN     NaN     NaN     NaN
# 1            Afghanistan  468.58  468.58  468.58  468.58  468.58  468.58
# 2  Akrotiri and Dhekelia     NaN     NaN     NaN     NaN     NaN     NaN
# 3                Albania  375.20  375.20  375.20  375.20  375.20  375.20
# 4                Algeria  460.21  460.21  460.21  460.21  460.21  460.21
#
#      1806    1807    1808  ...    2006   2007   2008   2009   2010   2011  \
# 0     NaN     NaN     NaN  ...     NaN    NaN    NaN    NaN    NaN    NaN
# 1  469.98  469.98  469.98  ...   116.3  113.2  110.4  107.6  105.0  102.3
# 2     NaN     NaN     NaN  ...     NaN    NaN    NaN    NaN    NaN    NaN
# 3  375.20  375.20  375.20  ...    19.5   18.7   17.9   17.3   16.6   16.0
# 4  460.21  460.21  460.21  ...    32.1   30.7   29.5   28.4   27.4   26.6
#
#    2012  2013  2014  2015
# 0   NaN   NaN   NaN   NaN
# 1  99.5  96.7  93.9  91.1
# 2   NaN   NaN   NaN   NaN
# 3  15.5  14.9  14.4  14.0
# 4  25.8  25.2  24.6  24.0
#
# [5 rows x 217 columns]
#                  Country     1800       1801       1802      1803       1804  \
# 0               Abkhazia      NaN        NaN        NaN       NaN        NaN
# 1            Afghanistan  28.2110  28.200753  28.190507  28.18026  28.170013
# 2  Akrotiri and Dhekelia      NaN        NaN        NaN       NaN        NaN
# 3                Albania  35.4000  35.400000  35.400000  35.40000  35.400000
# 4                Algeria  28.8224  28.822400  28.822400  28.82240  28.822400
#
#         1805      1806       1807       1808  ...    2006  2007  2008  2009  \
# 0        NaN       NaN        NaN        NaN  ...     NaN   NaN   NaN   NaN
# 1  28.159767  28.14952  28.139273  28.129027  ...    53.2  53.6  54.0  54.5
# 2        NaN       NaN        NaN        NaN  ...     NaN   NaN   NaN   NaN
# 3  35.400000  35.40000  35.400000  35.400000  ...    74.5  74.7  74.9  75.0
# 4  28.822400  28.82240  28.822400  28.822400  ...    74.8  75.0  75.3  75.6
#
#    2010  2011  2012  2013   2014   2015
# 0   NaN   NaN   NaN   NaN    NaN    NaN
# 1  54.8  55.2  55.5  56.2  56.91  57.63
# 2   NaN   NaN   NaN   NaN    NaN    NaN
# 3  75.2  75.5  75.7  75.8  75.90  76.00
# 4  75.9  76.1  76.2  76.3  76.40  76.50
#
# [5 rows x 217 columns]
#                  Country  1800  1801  1802  1803  1804  1805  1806  1807  \
# 0               Abkhazia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1            Afghanistan  7.00  7.00  7.00  7.00  7.00  7.00  7.00  7.00
# 2  Akrotiri and Dhekelia   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3                Albania  4.60  4.60  4.60  4.60  4.60  4.60  4.60  4.60
# 4                Algeria  6.99  6.99  6.99  6.99  6.99  6.99  6.99  6.99
#
#    1808  ...   2006  2007  2008  2009  2010  2011  2012  2013  2014  2015
# 0   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1  7.00  ...   6.70  6.46  6.20  5.93  5.66  5.40  5.14  4.90  4.68  4.47
# 2   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3  4.60  ...   1.85  1.80  1.76  1.74  1.74  1.75  1.76  1.77  1.78  1.78
# 4  6.99  ...   2.58  2.66  2.73  2.78  2.82  2.83  2.82  2.80  2.76  2.71
#
# [5 rows x 217 columns]

# %%
# grading cell - do not modify
display(population_df)
display(morttality_df)
display(life_exp_df)
display(fertility_df)
# Out:
#                                           Country        1800      1810  \
# 0                                        Abkhazia         NaN       NaN
# 1                                     Afghanistan     3280000   3280000
# 2                           Akrotiri and Dhekelia         NaN       NaN
# 3                                         Albania     410,445    423591
# 4                                         Algeria   2,503,218   2595056
# 5                                  American Samoa       8,170      8156
# 6                                         Andorra        2654      2654
# 7                                          Angola     1567028   1567028
# 8                                        Anguilla        2025      2025
# 9                             Antigua and Barbuda       37000     37000
# 10                                      Argentina      534000    534000
# 11                                        Armenia      413326    413326
# 12                                          Aruba       19286     19286
# 13                                      Australia     351,014    342440
# 14                                        Austria   3,205,587   3286650
# 15                                     Azerbaijan      879960    879960
# 16                                        Bahamas       27350     27350
# 17                                        Bahrain       64474     64474
# 18                                     Bangladesh  19,227,358  19611269
# 19                                       Barbados       81729     81729
# 20                                        Belarus     2355081   2355081
# 21                                        Belgium   3,138,137   3283959
# 22                                         Belize       25526     25526
# 23                                          Benin      636559    636559
# 24                                        Bermuda        9692     9,831
# 25                                         Bhutan       89989     89989
# 26                                        Bolivia     1100000   1100000
# 27                         Bosnia and Herzegovina      851806    851806
# 28                                       Botswana      121000    121000
# 29                                         Brazil   3,639,636   4058652
# ..                                            ...         ...       ...
# 245                                       Vanuatu       27791     27791
# 246                                     Venezuela      718000    718000
# 247                            West Bank and Gaza      165944    165944
# 248                                  West Germany         NaN       NaN
# 249                                Western Sahara        2788      2788
# 250                                       Vietnam     6551000   6551000
# 251                         Virgin Islands (U.S.)       40000     40000
# 252                          North Yemen (former)         NaN       NaN
# 253                          South Yemen (former)         NaN       NaN
# 254                                         Yemen     2593000   2593000
# 255                                    Yugoslavia         NaN       NaN
# 256                                        Zambia     747,000    747000
# 257                                      Zimbabwe     1085814   1085814
# 258                                         Åland         NaN       NaN
# 259                                   South Sudan   1,027,378   1041076
# 260                                       Curaçao         NaN       NaN
# 261                     Sint Maarten (Dutch part)         NaN       NaN
# 262                      St. Martin (French part)         NaN       NaN
# 263                                    Antarctica         NaN       NaN
# 264                                 Bouvet Island         NaN       NaN
# 265                British Indian Ocean Territory         NaN       NaN
# 266                                    Clipperton         NaN       NaN
# 267           French Southern and Antarctic Lands         NaN       NaN
# 268                                    Gaza Strip         NaN       NaN
# 269                    Heard and McDonald Islands         NaN       NaN
# 270                             Northern Marianas         NaN       NaN
# 271  South Georgia and the South Sandwich Islands         NaN       NaN
# 272                     US Minor Outlying Islands         NaN       NaN
# 273                                Virgin Islands         NaN       NaN
# 274                                     West Bank         NaN       NaN
#
#          1820      1830      1840      1850      1860      1870      1880  \
# 0         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1     3323519   3448982   3625022   3810047   3973968   4169690   4419695
# 2         NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 3      438671    457234    478227    506889    552800    610036    672544
# 4     2713079   2880355   3082721   3299305   3536468   3811028   4143163
# 5        8142      8128      8114      7958      7564      7057      6582
# 6        2700      2835      3026      3230      3436      3654      3885
# 7     1597530   1686390   1813100   1949329   2110747   2285417   2473597
# 8        2064      2177      2338      2511      2693      2888      3097
# 9       37000     37000     37000     37000     36532     35546     35222
# 10     570719    686703    873747   1113189   1421333   1856886   2493156
# 11     423527    453507    496835    544302    595928    652450    713957
# 12      19555     20332     21423     22574     23786     25063     26404
# 13     334002    348143    434095    742619   1256048   1724213   2253007
# 14    3391206   3538286   3728381   3962619   4235926   4556658   4947026
# 15     901772    965887   1058574   1160156   1270556   1391460   1523060
# 16      27404     27558     27768     29372     33625     38787     43344
# 17      64474     64474     64474     64474     64469     65422     68170
# 18   20122865  20872777  21776468  22719284  23665237  24757994  26094931
# 19      85456     96798    114080    132965    149452    161206    171072
# 20    2413420   2584900   2832789   3104450   3404323   3733161   4091588
# 21    3475782   3751571   4087429   4426000   4753088   5110891   5572208
# 22      25556     25641     25756     25872     25755     25745     27123
# 23     653348    702829    774654    853818    941469   1038118   1144003
# 24       9808      9315      9557     10786     11682     12414     13622
# 25      91144     94472     99137    104032    109811    115908    122321
# 26    1121924   1185846   1277104   1363412   1454100   1538001   1626132
# 27     871970    931129   1016407   1109495   1210294   1320249   1439493
# 28     121000    121000    121000    121000    121300    121600    121900
# 29    4582325   5301068   6206694   7254194   8466005   9964419  11893392
# ..        ...       ...       ...       ...       ...       ...       ...
# 245     28098     28979     30208     31490     32791     34145     35552
# 246    759249    887197   1087948   1298076   1500530   1719628   2015985
# 247    165944    165944    165944    169606    181738    201057    224771
# 248       NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# 267         NaN         NaN         NaN         NaN         NaN
# 268         NaN         NaN         NaN         NaN         NaN
# 269         NaN         NaN         NaN         NaN         NaN
# 270         NaN         NaN         NaN         NaN         NaN
# 271         NaN         NaN         NaN         NaN         NaN
# 272         NaN         NaN         NaN         NaN         NaN
# 273         NaN         NaN         NaN         NaN         NaN
# 274         NaN         NaN         NaN         NaN         NaN
#
# [275 rows x 82 columns]
#                                           Country    1800    1801    1802  \
# 0                                        Abkhazia     NaN     NaN     NaN
# 1                                     Afghanistan  468.58  468.58  468.58
# 2                           Akrotiri and Dhekelia     NaN     NaN     NaN
# 3                                         Albania  375.20  375.20  375.20
# 4                                         Algeria  460.21  460.21  460.21
# 5                                  American Samoa     NaN     NaN     NaN
# 6                                         Andorra     NaN     NaN     NaN
# 7                                          Angola  485.68  485.68  485.68
# 8                                        Anguilla     NaN     NaN     NaN
# 9                             Antigua and Barbuda  473.60  469.77  465.97
# 10                                      Argentina  402.19  402.19  402.19
# 11                                        Armenia  371.20  370.71  370.23
# 12                                          Aruba     NaN     NaN     NaN
# 13                                      Australia  390.99  390.99  390.99
# 14                                        Austria  387.32  373.01  359.22
# 15                                     Azerbaijan  384.00  383.21  382.43
# 16                                        Bahamas  471.04  466.97  462.94
# 17                                        Bahrain  439.79  439.79  439.79
# 18                                     Bangladesh  507.88  507.88  507.88
# 19                                       Barbados  469.76  471.42  473.08
# 20                                        Belarus  365.67  365.67  365.67
# 21                                        Belgium  322.40  322.40  322.40
# 22                                         Belize  467.20  463.87  460.56
# 23                                          Benin  430.46  430.46  430.46
# 24                                        Bermuda     NaN     NaN     NaN
# 25                                         Bhutan  463.36  462.97  462.59
# 26                                        Bolivia  404.69  404.69  404.69
# 27                         Bosnia and Herzegovina  378.80  378.80  378.80
# 28                                       Botswana  397.20  397.20  397.20
# 29                                         Brazil  417.44  417.44  417.44
# ..                                            ...     ...     ...     ...
# 245                                       Vanuatu  426.24  423.86  421.48
# 246                                     Venezuela  414.89  414.89  414.89
# 247                            West Bank and Gaza  435.20  435.19  435.18
# 248                                  West Germany     NaN     NaN     NaN
# 249                                Western Sahara     NaN     NaN     NaN
# 250                                       Vietnam  417.44  417.44  417.44
# 251                         Virgin Islands (U.S.)     NaN     NaN     NaN
# 252                          North Yemen (former)     NaN     NaN     NaN
# 253                          South Yemen (former)     NaN     NaN     NaN
# 254                                         Yemen  540.44  540.44  540.44
# 255                                    Yugoslavia     NaN     NaN     NaN
# 256                                        Zambia  409.79  409.79  409.79
# 257                                      Zimbabwe  395.95  395.95  395.95
# 258                                         Åland     NaN     NaN     NaN
# 259                                   South Sudan  490.08  490.08  490.08
# 260                                       Curaçao     NaN     NaN     NaN
# 261                     Sint Maarten (Dutch part)     NaN     NaN     NaN
# 262                      St. Martin (French part)     NaN     NaN     NaN
# 263                                    Antarctica     NaN     NaN     NaN
# 264                                 Bouvet Island     NaN     NaN     NaN
# 265                British Indian Ocean Territory     NaN     NaN     NaN
# 266                                    Clipperton     NaN     NaN     NaN
aN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 25   6.67  ...   2.68  2.59  2.51  2.44  2.38  2.32  2.28  2.23  2.19  2.15
# 26   6.48  ...   3.63  3.55  3.48  3.41  3.36  3.31  3.26  3.22  3.18  3.14
# 27   5.91  ...   1.20  1.21  1.22  1.23  1.24  1.26  1.27  1.28  1.30  1.32
# 28   6.47  ...   2.96  2.91  2.86  2.81  2.76  2.71  2.67  2.62  2.58  2.54
# 29   6.26  ...   2.00  1.94  1.90  1.86  1.84  1.82  1.81  1.80  1.79  1.78
# ..    ...  ...    ...   ...   ...   ...   ...   ...   ...   ...   ...   ...
# 230  4.44  ...   1.78  1.79  1.80  1.80  1.80  1.80  1.80  1.80  1.80  1.79
# 231  6.40  ...   2.03  2.04  2.04  2.05  2.04  2.04  2.02  2.01  1.99  1.97
# 232  6.92  ...   2.20  2.17  2.15  2.12  2.10  2.08  2.06  2.04  2.02  2.00
# 233  6.22  ...   2.57  2.52  2.48  2.45  2.41  2.38  2.35  2.33  2.30  2.27
# 234   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 235   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 236  6.89  ...   6.51  6.43  6.34  6.25  6.16  6.06  5.96  5.87  5.77  5.67
# 237  7.50  ...   1.30  1.35  1.38  1.41  1.44  1.45  1.46  1.47  1.48  1.49
# 238  6.94  ...   2.07  2.00  1.95  1.90  1.87  1.84  1.82  1.80  1.78  1.77
# 239  5.40  ...   1.80  1.84  1.87  1.89  1.90  1.90  1.90  1.89  1.89  1.89
# 240  6.85  ...   2.11  2.12  2.07  2.00  1.93  1.90  1.90  1.98  1.97  1.97
# 241  5.94  ...   2.14  2.12  2.11  2.09  2.08  2.07  2.06  2.05  2.04  2.03
# 242   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 243  5.71  ...   2.48  2.47  2.46  2.44  2.41  2.38  2.34  2.31  2.28  2.25
# 244   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 245  6.60  ...   3.76  3.68  3.61  3.55  3.50  3.46  3.42  3.38  3.35  3.31
# 246  5.66  ...   2.60  2.56  2.53  2.50  2.47  2.44  2.42  2.39  2.36  2.34
# 247  6.97  ...   4.58  4.48  4.38  4.30  4.22  4.14  4.08  4.01  3.95  3.88
# 248   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 249  6.32  ...   2.63  2.59  2.55  2.51  2.47  2.43  2.40  2.36  2.33  2.30
# 250  4.70  ...   1.89  1.88  1.86  1.84  1.82  1.79  1.77  1.74  1.72  1.70
# 251  5.55  ...   2.34  2.39  2.44  2.47  2.49  2.50  2.50  2.49  2.47  2.45
# 252   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 253   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 254  6.88  ...   5.20  5.01  4.83  4.66  4.50  4.35  4.21  4.08  3.95  3.83
# 255   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 256  6.71  ...   5.93  5.91  5.88  5.85  5.81  5.77  5.73  5.69  5.64  5.59
# 257  6.75  ...   3.94  3.90  3.85  3.79  3.72  3.64  3.56  3.49  3.41  3.35
# 258   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 259   NaN  ...    NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [260 rows x 217 columns]

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# # Question 7 (10 pts)
# The data frames from the question above are organized such that rows are countries and columns are years.  Reorganize each data frame such that each row contains 3 columns: country, year, and a data value.  This is known as the long or tidy format.  For example, the population data frame columns start out as country, year, year, year, ..., year.  After reorganizing, the population data frame columns will contain only 3 columns: country, year, and population.  Save the reorganized data into new data frames named tidy_population_df, tidy_morttality_df, tidy_life_exp_df, and tidy_fertility_df.  You are free to use any means necessary to perform this task but the pandas melt function may be useful.

# %%
# your code here
year_list = list(population_df.columns.values)[1:]

tidy_population_df = pd.melt(population_df, id_vars = ['Country'], value_vars = year_list, var_name='Year', value_name='Population')
tidy_morttality_df = pd.melt(morttality_df, id_vars = ['Country'], value_vars = year_list, var_name='Year', value_name='morttality')
tidy_life_exp_df = pd.melt(life_exp_df, id_vars = ['Country'], value_vars = year_list, var_name='Year', value_name='life_exp')
tidy_fertility_df = pd.melt(fertility_df, id_vars = ['Country'], value_vars = year_list, var_name='Year', value_name='fertility')

# %%
# grading cell - do not modify
display(tidy_population_df)
print(tidy_population_df.size)
display(tidy_morttality_df)
print(tidy_morttality_df.size)
display(tidy_life_exp_df)
print(tidy_life_exp_df.size)
display(tidy_fertility_df)
print(tidy_fertility_df.size)
# Out:
#                                             Country  Year  Population
# 0                                          Abkhazia  1800         NaN
# 1                                       Afghanistan  1800     3280000
# 2                             Akrotiri and Dhekelia  1800         NaN
# 3                                           Albania  1800     410,445
# 4                                           Algeria  1800   2,503,218
# 5                                    American Samoa  1800       8,170
# 6                                           Andorra  1800        2654
# 7                                            Angola  1800     1567028
# 8                                          Anguilla  1800        2025
# 9                               Antigua and Barbuda  1800       37000
# 10                                        Argentina  1800      534000
# 11                                          Armenia  1800      413326
# 12                                            Aruba  1800       19286
# 13                                        Australia  1800     351,014
# 14                                          Austria  1800   3,205,587
# 15                                       Azerbaijan  1800      879960
# 16                                          Bahamas  1800       27350
# 17                                          Bahrain  1800       64474
# 18                                       Bangladesh  1800  19,227,358
# 19                                         Barbados  1800       81729
# 20                                          Belarus  1800     2355081
# 21                                          Belgium  1800   3,138,137
# 22                                           Belize  1800       25526
# 23                                            Benin  1800      636559
# 24                                          Bermuda  1800        9692
# 25                                           Bhutan  1800       89989
# 26                                          Bolivia  1800     1100000
# 27                           Bosnia and Herzegovina  1800      851806
# 28                                         Botswana  1800      121000
# 29                                           Brazil  1800   3,639,636
# ...                                             ...   ...         ...
# 22245                                       Vanuatu  2015      264652
# 22246                                     Venezuela  2015    31108083
# 22247                            West Bank and Gaza  2015     4668466
# 22248                                  West Germany  2015         NaN
# 22249                                Western Sahara  2015      572540
# 22250                                       Vietnam  2015    93447601
# 22251                         Virgin Islands (U.S.)  2015      106291
# 22252                          North Yemen (former)  2015         NaN
# 22253                          South Yemen (former)  2015         NaN
# 22254                                         Yemen  2015    26832215
# 22255                                    Yugoslavia  2015         NaN
# 22256                                        Zambia  2015    16211767
# 22257                                      Zimbabwe  2015    15602751
# 22258                                         Åland  2015         NaN
# 22259                                   South Sudan  2015    12339812
# 22260                                       Curaçao  2015      157203
# 22261                     Sint Maarten (Dutch part)  2015       38745
# 22262                      St. Martin (French part)  2015         NaN
# 22263                                    Antarctica  2015         NaN
# 22264                                 Bouvet Island  2015         NaN
# 22265                British Indian Ocean Territory  2015         NaN
# 22266                                    Clipperton  2015         NaN
# 22267           French Southern and Antarctic Lands  2015         NaN
# 22268                                    Gaza Strip  2015         NaN
# 22269                    Heard and McDonald Islands  2015         NaN
# 22270                             Northern Marianas  2015         NaN
# 22271  South Georgia and the South Sandwich Islands  2015         NaN
# 22272                     US Minor Outlying Islands  2015         NaN
# 22273                                Virgin Islands  2015         NaN
# 22274                                     West Bank  2015         NaN
#
# [22275 rows x 3 columns]
# 66825
#                                             Country  Year  morttality
# 0                                          Abkhazia  1800         NaN
# 1                                       Afghanistan  1800      468.58
# 2                             Akrotiri and Dhekelia  1800         NaN
# 3                                           Albania  1800      375.20
# 4                                           Algeria  1800      460.21
# 5                                    American Samoa  1800         NaN
# 6                                           Andorra  1800         NaN
# 7                                            Angola  1800      485.68
# 8                                          Anguilla  1800         NaN
# 9                               Antigua and Barbuda  1800      473.60
# 10                                        Argentina  1800      402.19
# 11                                          Armenia  1800      371.20
# 12                                            Aruba  1800         NaN
# 13                                        Australia  1800      390.99
# 14                                          Austria  1800      387.32
# 15                                       Azerbaijan  1800      384.00
# 16                                          Bahamas  1800      471.04
# 17                                          Bahrain  1800      439.79
# 18                                       Bangladesh  1800      507.88
# 19                                         Barbados  1800      469.76
# 20                                          Belarus  1800      365.67
# 21                                          Belgium  1800      322.40
# 22                                           Belize  1800      467.20
# 23                                            Benin  1800      430.46
# 24                                          Bermuda  1800         NaN
# 25                                           Bhutan  1800      463.36
# 26                                          Bolivia  1800      404.69
# 27                           Bosnia and Herzegovina  1800      378.80
# 28                                         Botswana  1800      397.20
# 29                                           Brazil  1800      417.44
# ...                                             ...   ...         ...
# 22245                                       Vanuatu  2015       27.50
# 22246                                     Venezuela  2015       14.90
# 22247                            West Bank and Gaza  2015       21.10
# 22248                                  West Germany  2015         NaN
# 22249                                Western Sahara  2015       41.45
# 22250                                       Vietnam  2015       21.70
# 22251                         Virgin Islands (U.S.)  2015       10.33
# 22252                          North Yemen (former)  2015         NaN
# 22253                          South Yemen (former)  2015         NaN
# 22254                                         Yemen  2015       47.50
# 22255                                    Yugoslavia  2015         NaN
# 22256                                        Zambia  2015       67.80
# 22257                                      Zimbabwe  2015       79.60
# 22258                                         Åland  2015         NaN
# 22259                                   South Sudan  2015       92.60
# 22260                                       Curaçao  2015       11.33
# 22261                     Sint Maarten (Dutch part)  2015         NaN
# 22262                      St. Martin (French part)  2015         NaN
# 22263                                    Antarctica  2015         NaN
# 22264                                 Bouvet Island  2015         NaN
# 22265                British Indian Ocean Territory  2015         NaN
# 22266                                    Clipperton  2015         NaN
# 22267           French Southern and Antarctic Lands  2015         NaN
# 22268                                    Gaza Strip  2015         NaN
# 22269                    Heard and McDonald Islands  2015         NaN
# 22270                             Northern Marianas  2015         NaN
# 22271  South Georgia and the South Sandwich Islands  2015         NaN
# 22272                     US Minor Outlying Islands  2015         NaN
# 22273                                Virgin Islands  2015         NaN
# 22274                                     West Bank  2015         NaN
#
# [22275 rows x 3 columns]
# 66825
#                         Country  Year  life_exp
# 0                      Abkhazia  1800       NaN
# 1                   Afghanistan  1800   28.2110
# 2         Akrotiri and Dhekelia  1800       NaN
# 3                       Albania  1800   35.4000
# 4                       Algeria  1800   28.8224
# 5                American Samoa  1800       NaN
# 6                       Andorra  1800       NaN
# 7                        Angola  1800   26.9800
# 8                      Anguilla  1800       NaN
# 9           Antigua and Barbuda  1800   33.5360
# 10                    Argentina  1800   33.2000
# 11                      Armenia  1800   33.9950
# 12                        Aruba  1800   34.4190
# 13                    Australia  1800   34.0500
# 14                      Austria  1800   34.4000
# 15                   Azerbaijan  1800   29.1650
# 16                      Bahamas  1800   35.1790
# 17                      Bahrain  1800   30.3000
# 18                   Bangladesh  1800   25.5000
# 19                     Barbados  1800   32.1240
# 20                      Belarus  1800   36.2000
# 21                      Belgium  1800   40.0000
# 22                       Belize  1800   26.5000
# 23                        Benin  1800   31.0000
# 24                      Bermuda  1800       NaN
# 25                       Bhutan  1800   28.7990
# 26                      Bolivia  1800   33.0000
# 27       Bosnia and Herzegovina  1800   35.1000
# 28                     Botswana  1800   33.6000
# 29                       Brazil  1800   32.0000
# ...                         ...   ...       ...
# 21030       Trinidad and Tobago  2015   71.4000
# 21031                   Tunisia  2015   77.3000
# 21032                    Turkey  2015   76.5000
# 21033              Turkmenistan  2015   67.9000
# 21034  Turks and Caicos Islands  2015       NaN
# 21035                    Tuvalu  2015       NaN
# 21036                    Uganda  2015   60.8000
# 21037                   Ukraine  2015   72.1000
# 21038      United Arab Emirates  2015   76.6000
# 21039            United Kingdom  2015   81.4000
# 21040             United States  2015   79.1000
# 21041                   Uruguay  2015   77.3000
# 21042                      USSR  2015       NaN
# 21043                Uzbekistan  2015   70.1000
# 21044          Wallis et Futuna  2015       NaN
# 21045                   Vanuatu  2015   65.0000
# 21046                 Venezuela  2015   75.8000
# 21047        West Bank and Gaza  2015   75.2000
# 21048              West Germany  2015       NaN
# 21049            Western Sahara  2015       NaN
# 21050                   Vietnam  2015   76.5000
# 21051     Virgin Islands (U.S.)  2015       NaN
# 21052      North Yemen (former)  2015       NaN
# 21053      South Yemen (former)  2015       NaN
# 21054                     Yemen  2015   67.6000
# 21055                Yugoslavia  2015       NaN
# 21056                    Zambia  2015   58.9600
# 21057                  Zimbabwe  2015   60.0100
# 21058                     Åland  2015       NaN
# 21059               South Sudan  2015   58.0000
#
# [21060 rows x 3 columns]
# 63180
#                         Country  Year  fertility
# 0                      Abkhazia  1800        NaN
# 1                   Afghanistan  1800       7.00
# 2         Akrotiri and Dhekelia  1800        NaN
# 3                       Albania  1800       4.60
# 4                       Algeria  1800       6.99
# 5                American Samoa  1800        NaN
# 6                       Andorra  1800        NaN
# 7                        Angola  1800       6.93
# 8                      Anguilla  1800        NaN
# 9           Antigua and Barbuda  1800       5.00
# 10                    Argentina  1800       6.80
# 11                      Armenia  1800       7.80
# 12                        Aruba  1800       5.64
# 13                    Australia  1800       6.50
# 14                      Austria  1800       5.10
# 15                   Azerbaijan  1800       8.10
# 16                      Bahamas  1800       5.90
# 17                      Bahrain  1800       7.03
# 18                   Bangladesh  1800       6.70
# 19                     Barbados  1800       4.96
# 20                      Belarus  1800       7.00
# 21                      Belgium  1800       4.85
# 22                       Belize  1800       6.69
# 23                        Benin  1800       5.55
# 24                      Bermuda  1800        NaN
# 25                       Bhutan  1800       6.67
# 26                      Bolivia  1800       6.48
# 27       Bosnia and Herzegovina  1800       5.91
# 28                     Botswana  1800       6.47
# 29                       Brazil  1800       6.26
# ...                         ...   ...        ...
# 21030       Trinidad and Tobago  2015       1.79
# 21031                   Tunisia  2015       1.97
# 21032                    Turkey  2015       2.00
# 21033              Turkmenistan  2015       2.27
# 21034  Turks and Caicos Islands  2015        NaN
# 21035                    Tuvalu  2015        NaN
# 21036                    Uganda  2015       5.67
# 21037                   Ukraine  2015       1.49
# 21038      United Arab Emirates  2015       1.77
# 21039            United Kingdom  2015       1.89
# 21040             United States  2015       1.97
# 21041                   Uruguay  2015       2.03
# 21042                      USSR  2015        NaN
# 21043                Uzbekistan  2015       2.25
# 21044          Wallis et Futuna  2015        NaN
# 21045                   Vanuatu  2015       3.31
# 21046                 Venezuela  2015       2.34
# 21047        West Bank and Gaza  2015       3.88
# 21048              West Germany  2015        NaN
# 21049            Western Sahara  2015       2.30
# 21050                   Vietnam  2015       1.70
# 21051     Virgin Islands (U.S.)  2015       2.45
# 21052      North Yemen (former)  2015        NaN
# 21053      South Yemen (former)  2015        NaN
# 21054                     Yemen  2015       3.83
# 21055                Yugoslavia  2015        NaN
# 21056                    Zambia  2015       5.59
# 21057                  Zimbabwe  2015       3.35
# 21058                     Åland  2015        NaN
# 21059                     Åland  2015        NaN
#
# [21060 rows x 3 columns]
# 63180

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# # Question 8 (10 pts)
# Join all 4 dataframes together such that the country, year, population, mortality, life expectancy, and fertility columns are collected together in the same dataframe.  The join operation should not throw away any data.  Name the new dataframe concat_df.  Next, delete all rows where the data values (values other than country and year) are all NaN values.  Only drop the row if ALL the data values are NaN.

# %%
# your code here
concat_df = pd.merge(tidy_population_df, tidy_morttality_df, on=('Country', 'Year'), how = 'outer').merge(tidy_life_exp_df, on = ('Country', 'Year'), how = 'outer').merge(tidy_fertility_df, on=('Country', 'Year'), how = 'outer')
concat_df = concat_df.dropna(subset=['Population','morttality','life_exp','fertility'], how='all')
concat_df.head()
# Out:
#           Country  Year Population  morttality  life_exp  fertility
# 1     Afghanistan  1800    3280000      468.58   28.2110       7.00
# 3         Albania  1800    410,445      375.20   35.4000       4.60
# 4         Algeria  1800  2,503,218      460.21   28.8224       6.99
# 5  American Samoa  1800      8,170         NaN       NaN        NaN
# 6         Andorra  1800       2654         NaN       NaN        NaN

# %%
# grading cell - do not modify
display(concat_df.head())
print(concat_df.shape)

# %% [markdown]
# ##### Grading Feedback Cell

# %% [markdown]
# # Question 9 (10 pts)
# Using concat_df, report the child mortality rate and life expectancy in in 2015 for these 5 countries:
# 1. Sri Lanka
# 2. Poland
# 3. Malaysia
# 4. Pakistan
# 5. Thailand

# %%
# Your code here
filter = ['Sri Lanka', 'Poland', 'Malaysia', 'Pakistan', 'Thailand']
print (concat_df.loc[concat_df['Country'].isin(filter) & (concat_df['Year'] == '2015'), ("Country", "morttality", "life_exp")])
# Out:
#          Country  morttality  life_exp
# 22215   Malaysia         8.2      75.1
# 22251   Pakistan        81.1      66.5
# 22259     Poland         5.2      77.3
# 22293  Sri Lanka         8.7      76.5
# 22304   Thailand        12.3      75.1

# %% [markdown]
# ##### Grading Feedback Cell
